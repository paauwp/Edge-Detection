# %% [markdown]
# # How to Perform Edge Detection in Python using OpenCV

# %% [markdown]
# [ARTIKEL](https://www.thepythoncode.com/article/canny-edge-detection-opencv-python?utm_source=newsletter&utm_medium=email&utm_campaign=newsletter)
#
# Edge detection is an image processing technique for finding the boundaries of objects within images. It mainly works by detecting discontinuities in brightness. One of the most popular and widely used algorithm is Canny edge detector.
#
# Canny edge detector is an edge detection operator that uses multi-stage algorithm to detect a wide range of edges in images.
#
# The main stages are:
#
# - Filtering out noise using [Gaussian blur](https://en.wikipedia.org/wiki/Gaussian_blur) algorithm.
# - Finding the strength and direction of edges using [Sobel Filters](https://en.wikipedia.org/wiki/Sobel_operator)
# - Isolating the strongest edges and thin them to one-pixel wide lines by applying [non-maximum suppression](https://www.pyimagesearch.com/2014/11/17/non-maximum-suppression-object-detection-python/)
# - Using [hysteresis](https://en.wikipedia.org/wiki/Hysteresis) to isolate the best edges.
#
# Learn more [here](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_canny/py_canny.html) about the theory behind Canny edge detector.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read the image
image = cv2.imread("littleflower.jpg")

# %%
# convert it to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# show the grayscale image
plt.imshow(gray, cmap="gray")
plt.show()

# %% [markdown]
# All we need to do now, is to pass this image to cv2.Canny() function which finds edges in the input image and marks them in the output map edges using the Canny algorithm:

# %%
# perform the canny edge detector to detect image edges
edges = cv2.Canny(gray, threshold1=30, threshold2=100)

# %% [markdown]
# The smallest value between threshold1 and threshold2 is used for edge linking. The largest value is used to find initial segments of strong edges.
#
# Let's see the resulting image:

# %%
plt.imshow(edges, cmap="gray")
plt.show()

# %% [markdown]
# Interesting, try to fine tune the threshold values and see if you can make it better.

# %% [markdown]
# If you want to use the live camera, here is the full code for that:

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

while True:
    _, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 30, 100)
    cv2.imshow("edges", edges)
    cv2.imshow("gray", gray)
    if cv2.waitKey(1) == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
